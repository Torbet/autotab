# %%
import sys

sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# %matplotlib inline

# %%
data = np.load('../data/test_data_solo.npz')
tabs = data['tabs']
audio = data['audio']
# Out:
# (180, 80, 3000)

# %%
with open('../results/tiny_ft_20_0.0001_0.001_1.0_8_confusion.txt', 'r') as f:
  confusion = ast.literal_eval(f.read())

confusion = np.array(confusion)
confusion = confusion / np.sum(confusion, axis=1)[:, np.newaxis]

plt.figure(figsize=(10, 10))
sns.heatmap(confusion, annot=False, cmap='viridis')
# Out:
# <Axes: >
